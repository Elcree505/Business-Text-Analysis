# %%
from fastapi import FastAPI
from schemas.meeting import MeetingInput
from schemas.result import AnalysisResult
from services.analyzer import analyze
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       2 from schemas.meeting import MeetingInput
#       3 from schemas.result import AnalysisResult
# ----> 4 from services.analyzer import analyze
#
# File ~\OneDrive\Documents\Desktop\business-meeting-analyzer\app\services\analyzer.py:1
# ----> 1 from app.services.preprocess import build_full_text
#       2 from app.services.rules import apply_rules
#       3 from app.services.scoring import to_score_and_label
#
# ModuleNotFoundError: No module named 'app'

# %%
app = FastAPI(title="Business Meeting Analyzer")

@app.get("/health")
def health():
    return {"status": "ok"}

@app.post("/analyze", response_model=AnalysisResult)
def analyze_one(meeting: MeetingInput):
    out = analyze(meeting.title, meeting.description or "")
    return AnalysisResult(**out)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3 @app.get("/health")
#       4 def health():
#       5     return {"status": "ok"}
# ----> 7 @app.post("/analyze", response_model=AnalysisResult)
#       8 def analyze_one(meeting: MeetingInput):
#       9     out = analyze(meeting.title, meeting.description or "")
#      10     return AnalysisResult(**out)
#
# NameError: name 'AnalysisResult' is not defined
